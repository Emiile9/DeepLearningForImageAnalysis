# %% [markdown]
# # TP1 — Part 3: CNNs + Data Augmentation on MNIST (Rotation & Translation)
#
# **Course:** Deep Learning for Image Analysis / Computer Vision
# **Goal:** Train a **CNN** on MNIST, **inspect its layers**, and show how **data augmentation** (rotation + translation) can improve robustness.
#
# In Part 2, we used an MLP and **flattened** images into vectors.
# In Part 3, we use **CNNs** to exploit spatial structure **(1, 28, 28)** and we test a key idea in vision:
# > If we train with rotated/translated images, the model generalizes better to these transformations.
#
# ---
# ## What you will do
# 1. Train a baseline CNN on MNIST (no augmentation)
# 2. Train the same CNN with **RandomAffine** augmentation (rotation + translation)
# 3. Compare test accuracy on:
#    - **standard MNIST test**
#    - **transformed MNIST test** (rotated/translated)
# ---

# %% [markdown]
# ## 0) Setup (Colab GPU)
#
# In Colab: **Runtime → Change runtime type → GPU**
# Then run the cell below.

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Using device: cpu

# %% [markdown]
# ## 1) Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt

import plotly.express as px
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2) Data: MNIST + Augmentations
#
# We will create **four** dataset variants:
#
# 1. **Train (no aug)**: standard MNIST training set
# 2. **Train (aug)**: MNIST with *rotation + translation*
# 3. **Test (standard)**: standard MNIST test set
# 4. **Test (transformed)**: MNIST test set **with the same types of transforms** (to evaluate robustness)
#
# ### Augmentation used
# - Rotation: up to ±35 degrees
# - Translation: up to 30% of the image size
#
# This simulates real-world variation (digits rarely appear perfectly centered).

# %%
torch.manual_seed(0)

# Standard transform
tfm_standard = transforms.ToTensor()

# Augmentation: rotation + translation (applied during training)
tfm_aug = transforms.Compose([
    transforms.RandomAffine(
        degrees=35,
        translate=(0.3, 0.3)
    ),
    transforms.ToTensor()
])

# "Transformed test" to measure robustness to these changes
tfm_test_transformed = transforms.Compose([
        transforms.RandomAffine(
        degrees=35,
        translate=(0.3, 0.3)
    ),
    transforms.ToTensor()
])

# Datasets
train_noaug = torchvision.datasets.MNIST(
    root="./data",
    train=True,
    download=True,
    transform=tfm_standard
)
train_aug = torchvision.datasets.MNIST(
    root="./data",
    train=True,
    download=True,
    transform=tfm_aug
)

test_std = torchvision.datasets.MNIST(
    root="./data",
    train=False,
    download=True,
    transform=tfm_standard
)
test_trans = torchvision.datasets.MNIST(
    root="./data",
    train=False,
    download=True,
    transform=tfm_test_transformed
)

len(train_noaug), len(train_aug), len(test_std), len(test_trans)
# Out:
# (60000, 60000, 10000, 10000)

# %% [markdown]
# ### Quick visualization (standard vs augmented)
#
# If augmentation is working, you should see digits slightly rotated and shifted.

# %%
def show_samples(dataset, title, n=8):
    plt.figure(figsize=(12, 2))
    for i in range(n):
        img, label = dataset[i]
        plt.subplot(1, n, i+1)
        plt.imshow(img.squeeze(0), cmap="gray")
        plt.title(str(label))
        plt.axis("off")
    plt.suptitle(title)
    plt.show()

show_samples(train_noaug, "MNIST (standard samples)")
show_samples(train_aug, "MNIST (augmented samples: rotated/translated)")

# %% [markdown]
# ## 3) DataLoaders
#
# We'll use mini-batches. If you run out of memory, reduce `batch_size`.

# %%
batch_size = 128

train_loader_noaug = DataLoader(
    train_noaug,
    batch_size=batch_size,
    shuffle=True,
)
train_loader_aug   = DataLoader(
    train_aug,
    batch_size=batch_size,
    shuffle=True,
)
test_loader_std = DataLoader(
    test_std,
    batch_size=batch_size,
    shuffle=False
)
test_loader_trans = DataLoader(
    test_trans,
    batch_size=batch_size,
    shuffle=False
)

# %% [markdown]
# ## 4) CNN model
#
# A simple CNN for MNIST:
#
# - Conv(1→16) + ReLU + MaxPool
# - Conv(16→32) + ReLU + MaxPool
# - Flatten
# - FC(32×7×7 → 128) + ReLU
# - FC(128 → 10)
#
# This is intentionally small so it trains quickly on Colab.

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),  # 28x28 -> 14x14

            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)   # 14x14 -> 7x7
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32 * 7 * 7, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

model = SimpleCNN().to(device)
model
# Out:
# SimpleCNN(
#   (features): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=1568, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## 5) Training & evaluation utilities
#
# We use:
# - Loss: `CrossEntropyLoss` (10 classes)
# - Optimizer: `Adam`
#
# We'll train the same architecture twice:
# 1) on standard MNIST (no aug)
# 2) on augmented MNIST (rotation + translation)

# %%
criterion = nn.CrossEntropyLoss()

def train_one_epoch(model, loader, optimizer):
    model.train()
    total_loss = 0.0
    correct = 0
    total = 0

    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    return total_loss / len(loader), correct / total

# TODO:  before evaluating the model
def evaluate(model, loader):
    model.eval()
    correct = 0
    total = 0
    total_loss = 0.0
    with torch.no_grad():
        for images, labels in loader:
            outputs = model(images.to(device))
            loss = criterion(outputs, labels.to(device))
            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels.to(device)).sum().item()
    return total_loss / len(loader), correct / total

# %% [markdown]
# ## 6) Train baseline CNN (no augmentation)
#
# You can increase `epochs` if you wants

# %%
def train_model(train_loader, epochs=3, lr=1e-3):
    model = SimpleCNN().to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)

    history = {"train_loss": [], "train_acc": [], "val_loss": [], "val_acc": []}

    for epoch in range(1, epochs + 1):
        tr_loss, tr_acc = train_one_epoch(model, train_loader, optimizer)
        va_loss, va_acc = evaluate(model, test_loader_std)

        history["train_loss"].append(tr_loss)
        history["train_acc"].append(tr_acc)
        history["val_loss"].append(va_loss)
        history["val_acc"].append(va_acc)

        print(f"Epoch {epoch}/{epochs} | train_loss={tr_loss:.4f} train_acc={tr_acc:.3f} | test_std_acc={va_acc:.3f}")
    return model, history

epochs = 20
cnn_noaug, hist_noaug = train_model(train_loader_noaug, epochs=epochs)
# Out:
# Epoch 1/20 | train_loss=0.2918 train_acc=0.916 | test_std_acc=0.972
# Epoch 2/20 | train_loss=0.0738 train_acc=0.977 | test_std_acc=0.985
# Epoch 3/20 | train_loss=0.0492 train_acc=0.984 | test_std_acc=0.986
# Epoch 4/20 | train_loss=0.0373 train_acc=0.989 | test_std_acc=0.988
# Epoch 5/20 | train_loss=0.0299 train_acc=0.991 | test_std_acc=0.991
# Epoch 6/20 | train_loss=0.0245 train_acc=0.992 | test_std_acc=0.990
# Epoch 7/20 | train_loss=0.0200 train_acc=0.994 | test_std_acc=0.990
# Epoch 8/20 | train_loss=0.0165 train_acc=0.995 | test_std_acc=0.989
# Epoch 9/20 | train_loss=0.0137 train_acc=0.996 | test_std_acc=0.989
# Epoch 10/20 | train_loss=0.0117 train_acc=0.996 | test_std_acc=0.992
# Epoch 11/20 | train_loss=0.0086 train_acc=0.997 | test_std_acc=0.990
# Epoch 12/20 | train_loss=0.0087 train_acc=0.997 | test_std_acc=0.989
# Epoch 13/20 | train_loss=0.0072 train_acc=0.998 | test_std_acc=0.990
# Epoch 14/20 | train_loss=0.0079 train_acc=0.997 | test_std_acc=0.990
# Epoch 15/20 | train_loss=0.0055 train_acc=0.998 | test_std_acc=0.990
# Epoch 16/20 | train_loss=0.0065 train_acc=0.998 | test_std_acc=0.992
# Epoch 17/20 | train_loss=0.0041 train_acc=0.999 | test_std_acc=0.990
# Epoch 18/20 | train_loss=0.0044 train_acc=0.999 | test_std_acc=0.991
# Epoch 19/20 | train_loss=0.0048 train_acc=0.998 | test_std_acc=0.989
# Epoch 20/20 | train_loss=0.0037 train_acc=0.999 | test_std_acc=0.989

# %% [markdown]
# ### Compare training/validation loss and accuracy for different learning rates

# %%
results = {"learning_rates": [], "train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}
for lr in [1e-3, 1e-4, 1e-5]:
    print(f"Training with learning rate: {lr}.")
    cnn_noaug, hist_noaug = train_model(train_loader_noaug, epochs=epochs, lr=lr)
    results["learning_rates"].append(lr)
    results["train_loss"].append(hist_noaug["train_loss"][-1])
    results["val_loss"].append(hist_noaug["val_loss"][-1])
    results["train_acc"].append(hist_noaug["train_acc"][-1])
    results["val_acc"].append(hist_noaug["val_acc"][-1])
    print(f"Training with learning rate: {lr}, done.")
# Out:
# Training with learning rate: 0.001.
# Epoch 1/20 | train_loss=0.3003 train_acc=0.911 | test_std_acc=0.970
# Epoch 2/20 | train_loss=0.0738 train_acc=0.978 | test_std_acc=0.984
# Epoch 3/20 | train_loss=0.0505 train_acc=0.985 | test_std_acc=0.986
# Epoch 4/20 | train_loss=0.0381 train_acc=0.988 | test_std_acc=0.987
# Epoch 5/20 | train_loss=0.0311 train_acc=0.991 | test_std_acc=0.989
# Epoch 6/20 | train_loss=0.0252 train_acc=0.992 | test_std_acc=0.990
# Epoch 7/20 | train_loss=0.0217 train_acc=0.993 | test_std_acc=0.989
# Epoch 8/20 | train_loss=0.0176 train_acc=0.994 | test_std_acc=0.990
# Epoch 9/20 | train_loss=0.0148 train_acc=0.995 | test_std_acc=0.991
# Epoch 10/20 | train_loss=0.0130 train_acc=0.996 | test_std_acc=0.990
# Epoch 11/20 | train_loss=0.0110 train_acc=0.997 | test_std_acc=0.990
# Epoch 12/20 | train_loss=0.0087 train_acc=0.997 | test_std_acc=0.991
# Epoch 13/20 | train_loss=0.0080 train_acc=0.997 | test_std_acc=0.989
# Epoch 14/20 | train_loss=0.0066 train_acc=0.998 | test_std_acc=0.990
# Epoch 15/20 | train_loss=0.0097 train_acc=0.997 | test_std_acc=0.989
# Epoch 16/20 | train_loss=0.0054 train_acc=0.998 | test_std_acc=0.990
# Epoch 17/20 | train_loss=0.0042 train_acc=0.999 | test_std_acc=0.988
# Epoch 18/20 | train_loss=0.0033 train_acc=0.999 | test_std_acc=0.990
# Epoch 19/20 | train_loss=0.0052 train_acc=0.998 | test_std_acc=0.988
# Epoch 20/20 | train_loss=0.0051 train_acc=0.998 | test_std_acc=0.991
# Training with learning rate: 0.001, done.
# Training with learning rate: 0.0001.
# Epoch 1/20 | train_loss=0.9366 train_acc=0.793 | test_std_acc=0.906
# Epoch 2/20 | train_loss=0.2863 train_acc=0.916 | test_std_acc=0.935
# Epoch 3/20 | train_loss=0.2109 train_acc=0.938 | test_std_acc=0.948
# Epoch 4/20 | train_loss=0.1649 train_acc=0.951 | test_std_acc=0.960
# Epoch 5/20 | train_loss=0.1326 train_acc=0.960 | test_std_acc=0.968
# Epoch 6/20 | train_loss=0.1110 train_acc=0.968 | test_std_acc=0.971
# Epoch 7/20 | train_loss=0.0953 train_acc=0.972 | test_std_acc=0.976
# Epoch 8/20 | train_loss=0.0839 train_acc=0.975 | test_std_acc=0.978
# Epoch 9/20 | train_loss=0.0751 train_acc=0.978 | test_std_acc=0.979
# Epoch 10/20 | train_loss=0.0685 train_acc=0.980 | test_std_acc=0.981
# Epoch 11/20 | train_loss=0.0632 train_acc=0.982 | test_std_acc=0.984
# Epoch 12/20 | train_loss=0.0580 train_acc=0.983 | test_std_acc=0.984
# Epoch 13/20 | train_loss=0.0542 train_acc=0.984 | test_std_acc=0.985
# Epoch 14/20 | train_loss=0.0507 train_acc=0.985 | test_std_acc=0.985
# Epoch 15/20 | train_loss=0.0476 train_acc=0.986 | test_std_acc=0.984
# Epoch 16/20 | train_loss=0.0454 train_acc=0.987 | test_std_acc=0.986
# Epoch 17/20 | train_loss=0.0428 train_acc=0.987 | test_std_acc=0.987
# Epoch 18/20 | train_loss=0.0406 train_acc=0.988 | test_std_acc=0.986
# Epoch 19/20 | train_loss=0.0391 train_acc=0.988 | test_std_acc=0.987
# Epoch 20/20 | train_loss=0.0372 train_acc=0.989 | test_std_acc=0.987
# Training with learning rate: 0.0001, done.
# Training with learning rate: 1e-05.
# Epoch 1/20 | train_loss=2.2504 train_acc=0.367 | test_std_acc=0.600
# Epoch 2/20 | train_loss=2.0154 train_acc=0.659 | test_std_acc=0.705
# Epoch 3/20 | train_loss=1.5742 train_acc=0.723 | test_std_acc=0.768
# Epoch 4/20 | train_loss=1.1163 train_acc=0.786 | test_std_acc=0.827
# Epoch 5/20 | train_loss=0.8203 train_acc=0.824 | test_std_acc=0.848
# Epoch 6/20 | train_loss=0.6496 train_acc=0.847 | test_std_acc=0.868
# Epoch 7/20 | train_loss=0.5452 train_acc=0.863 | test_std_acc=0.881
# Epoch 8/20 | train_loss=0.4766 train_acc=0.875 | test_std_acc=0.889
# Epoch 9/20 | train_loss=0.4286 train_acc=0.884 | test_std_acc=0.897
# Epoch 10/20 | train_loss=0.3935 train_acc=0.891 | test_std_acc=0.903
# Epoch 11/20 | train_loss=0.3662 train_acc=0.897 | test_std_acc=0.907
# Epoch 12/20 | train_loss=0.3444 train_acc=0.902 | test_std_acc=0.909
# Epoch 13/20 | train_loss=0.3262 train_acc=0.906 | test_std_acc=0.913
# Epoch 14/20 | train_loss=0.3105 train_acc=0.910 | test_std_acc=0.916
# Epoch 15/20 | train_loss=0.2970 train_acc=0.914 | test_std_acc=0.920
# Epoch 16/20 | train_loss=0.2851 train_acc=0.918 | test_std_acc=0.922
# Epoch 17/20 | train_loss=0.2744 train_acc=0.920 | test_std_acc=0.924
# Epoch 18/20 | train_loss=0.2643 train_acc=0.923 | test_std_acc=0.927
# Epoch 19/20 | train_loss=0.2552 train_acc=0.926 | test_std_acc=0.929
# Epoch 20/20 | train_loss=0.2467 train_acc=0.928 | test_std_acc=0.930
# Training with learning rate: 1e-05, done.

# %%
df_results = pd.DataFrame(results)
fig = px.scatter(df_results, x="learning_rates", y=["train_loss", "val_loss", "train_acc", "val_acc"],
              labels={"value": "Loss/Accuracy", "learning_rates": "Learning Rate"},
              title="Training and Validation Loss/Accuracy vs Learning Rate after 3 epochs")
fig.show()

# %% [markdown]
# ## 7) Train CNN with augmentation (rotation + translation)
#
# Augmentation often makes training harder (samples are more varied), but increases robustness.

# %%
cnn_aug, hist_aug = train_model(train_loader_aug, epochs=epochs)
# Out:
# Epoch 1/20 | train_loss=1.3349 train_acc=0.545 | test_std_acc=0.890
# Epoch 2/20 | train_loss=0.5957 train_acc=0.815 | test_std_acc=0.934
# Epoch 3/20 | train_loss=0.4324 train_acc=0.868 | test_std_acc=0.940
# Epoch 4/20 | train_loss=0.3607 train_acc=0.889 | test_std_acc=0.950
# Epoch 5/20 | train_loss=0.3095 train_acc=0.905 | test_std_acc=0.956
# Epoch 6/20 | train_loss=0.2793 train_acc=0.913 | test_std_acc=0.956
# Epoch 7/20 | train_loss=0.2572 train_acc=0.921 | test_std_acc=0.969
# Epoch 8/20 | train_loss=0.2370 train_acc=0.925 | test_std_acc=0.959
# Epoch 9/20 | train_loss=0.2245 train_acc=0.931 | test_std_acc=0.973
# Epoch 10/20 | train_loss=0.2090 train_acc=0.935 | test_std_acc=0.967
# Epoch 11/20 | train_loss=0.2010 train_acc=0.938 | test_std_acc=0.970
# Epoch 12/20 | train_loss=0.1930 train_acc=0.941 | test_std_acc=0.974
# Epoch 13/20 | train_loss=0.1875 train_acc=0.942 | test_std_acc=0.973
# Epoch 14/20 | train_loss=0.1778 train_acc=0.943 | test_std_acc=0.975
# Epoch 15/20 | train_loss=0.1691 train_acc=0.947 | test_std_acc=0.974
# Epoch 16/20 | train_loss=0.1657 train_acc=0.948 | test_std_acc=0.980
# Epoch 17/20 | train_loss=0.1622 train_acc=0.950 | test_std_acc=0.978
# Epoch 18/20 | train_loss=0.1568 train_acc=0.951 | test_std_acc=0.976
# Epoch 19/20 | train_loss=0.1519 train_acc=0.952 | test_std_acc=0.978
# Epoch 20/20 | train_loss=0.1467 train_acc=0.954 | test_std_acc=0.979

# %% [markdown]
# ## 8) Evaluate robustness
#
# We evaluate both models on:
# - Standard MNIST test set
# - Transformed MNIST test set (rotated/translated)
#
# A robust model should lose **less accuracy** on the transformed test set.

# %%
noaug_std_loss, noaug_std_acc = evaluate(cnn_noaug, test_loader_std)
noaug_tr_loss,  noaug_tr_acc  = evaluate(cnn_noaug, test_loader_trans)
aug_std_loss,   aug_std_acc   = evaluate(cnn_aug, test_loader_std)
aug_tr_loss,    aug_tr_acc    = evaluate(cnn_aug, test_loader_trans)
print("=== Baseline CNN (no augmentation) ===")
print(f"Test (standard):    acc={noaug_std_acc:.3f}")
print(f"Test (transformed): acc={noaug_tr_acc:.3f}")
print()
print("=== CNN trained with augmentation ===")
print(f"Test (standard):    acc={aug_std_acc:.3f}")
print(f"Test (transformed): acc={aug_tr_acc:.3f}")
# Out:
# === Baseline CNN (no augmentation) ===
# Test (standard):    acc=0.930
# Test (transformed): acc=0.159
#
# === CNN trained with augmentation ===
# Test (standard):    acc=0.979
# Test (transformed): acc=0.954

# %% [markdown]
# ### Plot training curves (optional)

# %%
def plot_hist(hist, title):
    plt.figure(figsize=(10, 3))
    plt.plot(hist["train_acc"], label="train_acc")
    plt.plot(hist["val_acc"], label="test_std_acc")
    plt.title(title)
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.legend()
    plt.show()

plot_hist(hist_noaug, "CNN (no augmentation)")
plot_hist(hist_aug, "CNN (with augmentation)")

# %% [markdown]
# ## 9) Visualizing CNN layers
#
# We will look at:
# 1. **First-layer convolution filters** (weights of Conv1)
# 2. **Feature maps (activations)** for a single image
#
# This helps you *see* what the CNN learns.

# %%
def show_conv1_filters(model, max_filters=16):
    conv1 = None
    for layer in model.features:
        if isinstance(layer, nn.Conv2d):
            conv1 = layer
            break
    W = conv1.weight.detach().cpu()  # (out_channels, in_channels, kH, kW)

    n = min(W.shape[0], max_filters)
    plt.figure(figsize=(10, 2))
    for i in range(n):
        plt.subplot(1, n, i+1)
        plt.imshow(W[i, 0], cmap="gray")
        plt.axis("off")
    plt.suptitle("Conv1 filters (learned 3×3 kernels)")
    plt.show()

show_conv1_filters(cnn_aug)

# %% [markdown]
# ### Feature maps (activations)
#
# We take **one test image**, pass it through the CNN, and visualize outputs after each convolution layer.

# %%
@torch.no_grad()
def get_activations(model, x):
    activations = []
    cur = x
    for layer in model.features:
        cur = layer(cur)
        if isinstance(layer, nn.Conv2d):
            activations.append(cur.detach().cpu())
    return activations

# One sample from the standard test set
img, label = test_std[0]
x = img.unsqueeze(0).to(device)

acts = get_activations(cnn_aug, x)

print("Label:", label)
print("Activation shapes:", [a.shape for a in acts])
# Out:
# Label: 7
# Activation shapes: [torch.Size([1, 16, 28, 28]), torch.Size([1, 32, 14, 14])]

# %%
def show_feature_maps(activation, title, max_maps=8):
    C = activation.shape[1]
    n = min(C, max_maps)
    plt.figure(figsize=(12, 2))
    for i in range(n):
        plt.subplot(1, n, i+1)
        plt.imshow(activation[0, i], cmap="gray")
        plt.axis("off")
    plt.suptitle(title)
    plt.show()

for idx, act in enumerate(acts, start=1):
    show_feature_maps(act, f"Feature maps after Conv layer {idx}", max_maps=8)

# %% [markdown]
# ## 10) Final reflection
#
# 1. Compare **standard test accuracy** vs **transformed test accuracy** for both models. What do you notice?
# 2. Why does augmentation help on the transformed test set?
# 3. Do we always expect augmentation to improve standard test accuracy? Why/why not?
#
# Answers:
# 1. **Compare standard vs transformed test accuracy**:
#    - Baseline CNN (no aug): lower accuracy on transformed test set
#    - Augmented CNN: higher accuracy on transformed test set
# 2. Augmentation helps the model generalize to rotations and translations, which are common in real-world data.
# 3. We don't always expect augmentation to improve standard test accuracy, as it may introduce noise or distortions that don't match the original data distribution.
# **Conclusion:** In the next LAB(2), we will go deeper into CNN architectures, and you should see further accuracy improvements.
